# %% [markdown]
# <a href="https://colab.research.google.com/github/leidermota/Prueba/blob/main/SegundaEntrega_Mota.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto machine learning: "Predicción si el individuo gana más de 50K al año" 📈📉**
# Leider Mota - comisión 42365

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # **1. ¿Que se quiere resolver?** abstracto con motivación y audiencia, contexto comercial, problema comercial, contexto analítico

# %% [markdown]
# a➝ **Abstracto, Motivación y Audiencia:**
#
# La motivación detrás de este proyecto radica en el interés de entender los patrones y variables que determinan si una persona superará el umbral de ingresos de 50,000 dólares al año. Esto puede ser valioso para personas que buscan mejorar sus ingresos, para empresas que desean optimizar sus estrategias de mercado y para gobiernos que necesitan comprender la distribución de ingresos en la población.
#
# La audiencia objetivo de este proyecto incluye:
#
# Analistas y científicos de datos interesados en técnicas de predicción y clasificación.
# Empresas y organizaciones que buscan mejorar su enfoque de marketing y segmentación de clientes.
# Economistas y formuladores de políticas interesados en comprender la dinámica de ingresos en la sociedad.

# %% [markdown]
# b➝ **Contexto Comercial:**
#
# En el contexto comercial, esta predicción puede ayudar a empresas de distintos sectores a dirigir sus esfuerzos de marketing y ventas hacia segmentos específicos de la población con mayores probabilidades de tener ingresos más altos. Al identificar a los clientes potenciales con mayores ingresos, las empresas pueden adaptar sus productos y servicios para satisfacer mejor sus necesidades y, al mismo tiempo, optimizar sus recursos y estrategias de negocio.

# %% [markdown]
# c➝ **Problema Comercial:**
#
# El problema comercial que abordamos es la identificación de aquellos individuos que tienen mayores posibilidades de ganar más de 50,000 dólares al año. Esta clasificación permitirá a las empresas dirigirse a este grupo objetivo con mayor precisión, lo que a su vez puede aumentar la eficiencia y efectividad de sus esfuerzos de marketing y ventas.

# %% [markdown]
# d➝ **Contexto Analítico:**
#
# En el contexto analítico, utilizaremos técnicas avanzadas de aprendizaje automático y minería de datos para procesar y analizar un conjunto de datos previamente recolectado. Estos datos pueden incluir variables como edad, educación, ocupación, estado civil, ubicación, entre otras. A partir de esta información, desarrollaremos y evaluaremos modelos predictivos que nos permitan determinar qué individuos tienen más probabilidades de superar el umbral de ingresos establecido. La precisión y eficacia de estos modelos serán fundamentales para el éxito del proyecto y para brindar información valiosa a la audiencia objetivo.

# %% [markdown]
# e➝ **Hipótesis:**
#
#
# 1.   ¿Qué características definen que ganes más o menos de 50K al año?
# 2.   ¿Qué algoritmo será el mejor para predecir dicha variable?

# %% [markdown]
# # **2. Importación de librerías y conjunto de datos**
#
# En esta etapa, procederemos con la importación de las librerías necesarias y el conjunto de datos que utilizaremos para nuestro análisis, visualización y modelado.

# %% [markdown]
# a➝ **Librerías**

# %%
# librerias para el analisis de datos
import pandas as pd
import numpy as np

# librerias para graficacion
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Librerías para la importación de archivos
from google.colab import drive
import tarfile

# %%
# creando carpeta para importar archivos
drive.mount('carpeta')
# Out:
# Mounted at carpeta

# %%
# ubicando el archivo en la carpeta donde se encuentra el dataset
# %cd /content/carpeta/MyDrive/CoderHouse/Data Science 42365 Leider Mota/data
# Out:
# /content/carpeta/MyDrive/CoderHouse/Data Science 42365 Leider Mota/data

# %% [markdown]
# b➝ **Importación del conjunto de datos**

# %%
# importar dataset y indicando que el separador del csv sea una coma ","
adultos = pd.read_csv('adult.csv', sep = ',')

# %% [markdown]
# c➝ **Columnas del conjunto de datos:**
#
# A continuación, se presentan las diferentes columnas que componen el conjunto de datos, cada una con su respectiva descripción:
#
# *   Edad: Representa la edad del individuo registrado en años.
# *   Clase de trabajo: Indica la categoría o tipo de trabajo en el que está empleado el individuo.
# *   Fnlwgt: Es el peso final asignado al individuo durante el proceso de muestreo, utilizado para la estimación de la población.
# *   Educación: Refleja el nivel educativo alcanzado por el individuo (ej. escuela secundaria, licenciatura, posgrado, etc.).
# *   Número de Educación: Representa el número de años de educación completados por el individuo.
# *   Estado civil: Describe el estado civil del individuo (ej. soltero, casado, divorciado, etc.).
# *   Trabajo: Indica el tipo de ocupación que realiza el individuo.
# *   Relación: Describe la relación con respecto a la familia (ej. esposo, esposa, hijo, etc.).
# *   Raza: Representa la raza o etnia del individuo.
# *   Sexo: Indica el género del individuo (masculino o femenino).
# *   Plusvalía: Hace referencia a las ganancias de capital obtenidas por el individuo.
# *   Pérdida de Capital: Indica las pérdidas de capital sufridas por el individuo.
# *   Horas de trabajo por semana: Representa el número de horas trabajadas por semana.
# *   País Nativo: Indica el país de origen del individuo.
# *   Ingreso_y (Si gana o no gana más de 50k al año): Esta columna determina si el individuo gana más de 50,000 dólares al año (1) o no (0).

# %%
# eligiendo estilo para los graficos
mpl.style.use('bmh')

# %% [markdown]
# # **3. Introducción y preprocesamiento de datos**
#
# En esta sección, daremos una breve introducción a los datos utilizados en este proyecto, los cuales fueron extraídos de la base de datos de la Oficina del Censo de 1994, recopilados por Ronny Kohavi y Barry Becker en su trabajo sobre Data Mining and Visualization, en Silicon Graphics. El objetivo principal de esta tarea de predicción es determinar si una persona gana más de $50,000 al año.

# %% [markdown]
# ### a➝ **Análisis del conjunto de datos**

# %% [markdown]
# **Información general.**
#
# En esta sección, proporcionaremos una visión general de los datos presentes en el conjunto de datos.

# %%
# mostrando primera vista del dataframe
adultos.head(3)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
# 2                ?      Unmarried  Black  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K

# %%
# mostrar informacion que son relevantes en el dataframe
print('Dimensiones:\n', adultos.shape)
print('-------------------------------')
print('Nulos:\n:', adultos.isnull().sum())
print('-------------------------------')
print('Tipos de variables:', adultos.info())
print('-------------------------------')
# Out:
# Dimensiones:
#  (32561, 15)
# -------------------------------
# Nulos:
# : age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64
# -------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
# ...

# %% [markdown]
# Se puede observar que no existen datos nulos. Esto se debe a que los datos nulos están representados en el dataset como "?".

# %%
# reemplazando "?" por datos nulos
adultos = adultos.replace('?', np.nan)

# %%
# mostrando los nuevos datos nulos
print('Nulos:\n:', adultos.isnull().sum())
# Out:
# Nulos:
# : age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %% [markdown]
# También se puede observar que el dataframe está en inglés. La tarea consiste en traducir todas las columnas y filas.

# %% [markdown]
# ### b➝ **Traducción del conjunto de datos al español**

# %%
# traduciendo al espanol todas las columnas
adultos = adultos.rename(columns={
    'age': 'edad', 'workclass': 'clase_trabajo', 'fnlwgt': 'fnlwgt', 'education': 'educacion', 'education.num': 'educacion_num',
       'marital.status': 'estado_civil', 'occupation': 'trabajo', 'relationship': 'relacion', 'race': 'raza', 'sex': 'sexo',
       'capital.gain': 'plusvalia', 'capital.loss': 'perdida_capital', 'hours.per.week': 'horas_trabajo_semanal', 'native.country' : 'pais_nativo',
       'income': 'ingreso_y'
       })

# %%
# traduciendo al espanol todas las filas de la columna "pais_nativo"
adultos['pais_nativo'] = adultos['pais_nativo'].replace({
    'United-States': 'Estados Unidos',
    'Mexico': 'Mexico',
    'Greece': 'Grecia',
    'Vietnam': 'Vietnam',
    'China': 'China',
    'Taiwan': 'Taiwan',
    'India': 'India',
    'Philippines': 'Filipinas',
    'Trinadad&Tobago': 'Trinidad y Tobago',
    'Canada': 'Canada',
    'South': 'Sur',
    'Holand-Netherlands': 'Paises Bajos',
    'Puerto-Rico': 'Puerto Rico',
    'Poland': 'Polonia',
    'Iran': 'Irán',
    'England': 'Inglaterra',
    'Germany': 'Alemania',
    'Italy': 'Italia',
    'Japan': 'Japón',
    'Hong': 'Hong Kong',
    'Honduras': 'Honduras',
    'Cuba': 'Cuba',
    'Ireland': 'Irlanda',
    'Cambodia': 'Camboya',
    'Peru': 'Perú',
    'Nicaragua': 'Nicaragua',
    'Dominican-Republic': 'Republica Dominicana',
    'Haiti': 'Haiti',
    'El-Salvador': 'El Salvador',
    'Hungary': 'Hungria',
    'Columbia': 'Colombia',
    'Guatemala': 'Guatemala',
    'Jamaica': 'Jamaica',
    'Ecuador': 'Ecuador',
    'France': 'Francia',
    'Yugoslavia': 'Yugoslavia',
    'Scotland': 'Escocia',
    'Portugal': 'Portugal',
    'Laos': 'Laos',
    'Thailand': 'Tailandia',
    'Outlying-US(Guam-USVI-etc)': 'Territorios Exteriores de EE. UU.'
})

# %%
# traduciendo al espanol todas las filas de la columna "clase_trabajo"
adultos['clase_trabajo'] = adultos['clase_trabajo'].replace({
    'Private': 'Privado',
    'State-gov': 'Gobierno estatal',
    'Federal-gov': 'Gobierno federal',
    'Self-emp-not-inc': 'Autonomo sin incorporacion',
    'Self-emp-inc': 'Autonomo con incorporacion',
    'Local-gov': 'Gobierno local',
    'Without-pay': 'Sin remuneracion',
    'Never-worked': 'Nunca ha trabajado'

})

# %%
# traduciendo al espanol todas las filas de la columna "educacion"
adultos['educacion'] = adultos['educacion'].replace({
    'HS-grad': 'Graduado de escuela secundaria',
    'Some-college': 'Algo de universidad',
    'Doctorate': 'Doctorado',
    'Prof-school': 'Escuela profesional',
    'Bachelors': 'Licenciatura',
    'Masters': 'Maestria',
    'Assoc-acdm': 'Asociado - Administracion',
    'Assoc-voc': 'Asociado - Vocacional',
})

# simplificando columna educacion
adultos['educacion'] = adultos['educacion'].replace(['11th', '9th', '7th-8th', '5th-6th', '10th', '1st-4th', 'Preschool', '12th'],'Escuela')

# %%
# traduciendo al espanol todas las filas de la columna "estado_civil"
adultos['estado_civil'] = adultos['estado_civil'].replace({
    'Widowed': 'Viudo/a',
    'Divorced': 'Divorciado/a',
    'Separated': 'Separado/a',
    'Never-married': 'Soltero/a',
    'Married-civ-spouse': 'Casado/a - Cónyuge civil',
    'Married-spouse-absent': 'Casado/a - Conyuge ausente',
    'Married-AF-spouse': 'Casado/a - Conyuge en la Fuerza Aérea'
})

# %%
# traduciendo al espanol todas las filas de la columna "trabajo"
adultos['trabajo'] = adultos['trabajo'].replace({
    'Exec-managerial': 'Directivo ejecutivo',
    'Machine-op-inspct': 'Operador de maquinas e inspector',
    'Prof-specialty': 'Especialista profesional',
    'Other-service': 'Otros servicios',
    'Adm-clerical': 'Administrativo y de oficina',
    'Craft-repair': 'Artesano y reparación',
    'Transport-moving': 'Transporte y movimiento',
    'Handlers-cleaners': 'Manipuladores y limpiadores',
    'Sales': 'Ventas',
    'Farming-fishing': 'Agricultura y pesca',
    'Tech-support': 'Soporte tecnico',
    'Protective-serv': 'Servicios de proteccion',
    'Armed-Forces': 'Fuerzas Armadas',
    'Priv-house-serv': 'Servicio domestico privado'
})

# %%
# traduciendo al espanol todas las filas de la columna "relacion"
adultos['relacion'] = adultos['relacion'].replace({
    'Not-in-family': 'No en la familia',
    'Unmarried': 'Soltero/a',
    'Own-child': 'Hijo/a propio/a',
    'Other-relative': 'Otro pariente',
    'Husband': 'Esposo',
    'Wife': 'Esposa'
})

# %%
# traduciendo al espanol todas las filas de la columna "sexo"
adultos['sexo'] = adultos['sexo'].replace({
    'Female': 'Femenino',
    'Male': 'Masculino'
})

# %%
# traduciendo al espanol todas las filas de la columna "raza"
adultos['raza'] = adultos['raza'].replace({
    'White': 'Blanco',
    'Black': 'Negro',
    'Asian-Pac-Islander': 'Asiático de las Islas del Pacífico',
    'Other': 'Otro',
    'Amer-Indian-Eskimo': 'Indio Americano / Esquimal'
})

# %% [markdown]
# ### c➝ **Normalizando la columna (Y)**
#
# Podemos observar que los datos relacionados con la variable objetivo del modelo de machine learning no están correctamente normalizados para su inserción en el modelo. Es hora de realizar este proceso para adecuarlos debidamente.

# %%
# codigo condicional para crear nuevas columnas con datos mas aptos
adultos['<=50K'] = adultos['ingreso_y'].apply(lambda x: 1 if x == '<=50K' else 0)

adultos['>50K'] = adultos['ingreso_y'].apply(lambda x: 1 if x == '>50K' else 0)

# %% [markdown]
# # **4. Análisis Exploratorio de Datos (EDA)**
#
# En esta sección, llevaremos a cabo un análisis exploratorio de datos crítico y riguroso sobre el dataframe, con el propósito de extraer insights y correlaciones entre variables que nos ayuden a alcanzar los objetivos del proyecto.

# %% [markdown]
# ## a➝ **Valores atípicos**
#
# Se analizará la presencia de valores atípicos (outliers) en las columnas numéricas y, en caso de detectarlos, exploraremos posibles acciones a tomar con respecto a ellos.

# %% [markdown]
# ### ⇨ Histogramas

# %%
# seleccionar las columnas solo con datos numericos y eliminar las creadas para el modelo
adultos_numericas = adultos.select_dtypes(include='number')
adultos_numericas_solo = adultos_numericas.drop(['<=50K', '>50K'], axis=1)

# Calcular el número de filas y columnas para la cuadrícula de subparcelas
num_plots = len(adultos_numericas_solo.columns)
num_rows = (num_plots + 1) // 2
num_cols = 2

# Crear la cuadrícula de subparcelas
fig, axs = plt.subplots(num_rows, num_cols, figsize=(10, 10))

# Iterar sobre las columnas numéricas y generar los histogramas
for i, columna in enumerate(adultos_numericas_solo.columns):
    row = i // num_cols
    col = i % num_cols
    ax = axs[row, col] if num_rows > 1 else axs[col]
    sns.histplot(adultos[columna], bins=10, ax=ax)
    ax.set_title(columna)

# Ajustar los espacios entre las subparcelas
plt.tight_layout()

# Mostrar los histogramas
plt.show()

# %% [markdown]
# ### ⇨ Gráficos de caja

# %%
# Calcular el número de filas y columnas para la cuadrícula de subparcelas
num_plots = len(adultos_numericas_solo.columns)
num_rows = (num_plots + 1) // 2
num_cols = 2

# Crear la cuadrícula de subparcelas
fig, axs = plt.subplots(num_rows, num_cols, figsize=(10, 10))

# Iterar sobre las columnas numéricas y generar los boxplots
for i, columna in enumerate(adultos_numericas_solo.columns):
    row = i // num_cols
    col = i % num_cols
    ax = axs[row, col] if num_rows > 1 else axs[col]
    sns.boxplot(x=columna, data=adultos, ax=ax)
    ax.set_title(columna)

# Ajustar los espacios entre las subparcelas
plt.tight_layout()

# Mostrar los boxplots
plt.show()

# %% [markdown]
# Se detectaron varios valores atípicos (outliers) en algunas columnas, sin embargo, se decidió conservarlos, ya que se estima que son necesarios para el análisis.

# %% [markdown]
# ## b➝ **Graficos univariados**

# %%
# figura y barplot
plt.figure(figsize = (8,5))
eda_percentage = adultos['ingreso_y'].value_counts(normalize = True).rename_axis('ingreso_y').reset_index(name = 'Percentage')
ax = sns.barplot(x = 'ingreso_y', y = 'Percentage', data = eda_percentage.head(10), palette='Blues_r')

# titulo, axis y etiqueta de datos
plt.title('Distribucion de ingresos por adultos', fontsize=18, fontweight='bold')
plt.xlabel('Ingresos')
plt.ylabel('Porcentaje')


for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{height:.0%}', (x + width/2, y + height*1.02), ha='center', fontweight='bold')

# %% [markdown]
# ## c➝ **Graficos bivariados**

# %% [markdown]
# ### ⇨ Edad

# %%
# funcion para juntar las edades en grupos
def categoria_edad(x):
    x = int(x)
    x = abs(x)
    if( 18 < x < 31 ):
        return "19-30"
    if( 30 < x < 41 ):
        return "31-40"
    if( 40 < x < 51 ):
        return "41-50"
    if( 50 < x < 61 ):
        return "51-60"
    if( 60 < x < 71 ):
        return "61-70"
    else:
        return "Mayor que 70"

# aplicandolo a una nueva columna
adultos['categoria_edad'] = adultos['edad'].apply(categoria_edad)

# %%
# creando figura
plt.figure(figsize=(12,6))

# generando grafico
order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Mayor que 70']
sns.countplot(x=adultos['categoria_edad'], hue=adultos['ingreso_y'], order=order_list, palette='Blues_r')

# tituloS y leyendas
plt.title('Ingresos de Individuos de Diferentes Grupos de Edad', fontsize=18, fontweight='bold')
plt.xlabel('Edades')
plt.ylabel('Conteo')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado una observación interesante. Podemos notar que la cantidad de personas que ganan más de 50K dólares aumenta a medida que aumenta la edad, hasta cierto punto.
#
# Sin embargo, es notable que la cantidad de personas que ganan más de 50K resulta bastante insignificante en el grupo de edad de 19 a 30 años. Por otro lado, en los grupos de edad de 41-50 y 51-60, la cantidad de personas que ganan más de 50K es sorprendentemente comparable a las que ganan menos.
#
# Esta información sugiere que la edad puede estar relacionada con mayores ingresos, pero también resalta la importancia de investigar y entender las diferencias en los patrones salariales en diferentes grupos de edad para una interpretación más profunda de los datos.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ⇨ Educación

# %%
# indicando el tamano del marco
fig, ax =  plt.subplots(figsize=(15, 4))

# creando groupby para generar el grafico
educacion_y = adultos.groupby(['educacion', '>50K']).size().unstack(fill_value=0).reset_index()
educacion_y = educacion_y.rename(columns={0: '<=50K', 1: '>50K'})

# cambiandolo de formato
educacion_y_long = educacion_y.melt(id_vars='educacion', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# creando el grafico
sns.barplot(data=educacion_y_long, x='educacion', y='value', hue='variables', palette='Blues_r')

# configurando titulos y variables
plt.title('Conteo de ingresos por educacion', fontsize = 18, fontweight = 'bold')
plt.xlabel('Educacion')
plt.ylabel('Ganancias por personas')
plt.xticks(rotation=75)

# Añadir etiquetas de datos a cada barra
for p in ax.patches:
    ax.annotate(str(p.get_height()),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points',
                fontsize=8)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos hecho dos observaciones importantes basadas en los datos representados:
#
# 1.   Tener un doctorado, una maestría o haber cursado una escuela profesional aumenta significativamente las probabilidades de ganar más de 50K al año. Esto sugiere una fuerte correlación entre un nivel educativo más avanzado y mayores ingresos.
# 2.   Por otro lado, se nota que la falta de educación universitaria tiene un impacto significativamente negativo en la probabilidad de ganar más de 50K al año. Esto indica que la educación universitaria puede ser un factor determinante para alcanzar ingresos más altos.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
# calculando las probabilidades
educacion_y['total_educacion'] = educacion_y['<=50K'] + educacion_y['>50K']
educacion_y['probabilidad_>50K'] = ((educacion_y['>50K'] / educacion_y['total_educacion']) * 100).round(2)
educacion_y['probabilidad_<=50K'] = ((educacion_y['<=50K'] / educacion_y['total_educacion']) * 100).round(2)

#conviertiendo a formato float
educacion_y['probabilidad_>50K'] = educacion_y['probabilidad_>50K'].astype(float)
educacion_y['probabilidad_<=50K'] = educacion_y['probabilidad_<=50K'].astype(float)

educacion_y
# Out:
# >50K                       educacion  <=50K  >50K  total_educacion  \
# 0                Algo de universidad   5904  1387             7291
# 1          Asociado - Administracion    802   265             1067
# 2              Asociado - Vocacional   1021   361             1382
# 3                          Doctorado    107   306              413
# 4                            Escuela   4009   244             4253
# 5                Escuela profesional    153   423              576
# 6     Graduado de escuela secundaria   8826  1675            10501
# 7                       Licenciatura   3134  2221             5355
# 8                           Maestria    764   959             1723
#
# >50K  probabilidad_>50K  probabilidad_<=50K
# 0                 19.02               80.98
# 1                 24.84               75.16
# 2                 26.12               73.88
# 3                 74.09               25.91
# 4                  5.74               94.26
# ...

# %%
# Agrupar los datos por la columna "educacion" y calcular la suma de las columnas de porcentaje
grouped_data = educacion_y.groupby("educacion").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_>50K", "probabilidad_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax =  plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro de la educacion")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro de la educacion")

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Educacion")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar mas de 50K de cada educacion", fontsize=18, fontweight='bold')
plt.legend()
plt.xticks(rotation=75)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %%
# Agrupar los datos por la columna "educacion" y calcular la suma de las columnas de porcentaje
grouped_data = educacion_y.groupby("educacion").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_>50K", "probabilidad_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax =  plt.subplots(figsize=(12, 3))
plt.bar(categorias, datos_columnas[0])
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0])

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Educacion")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar mas de 50K de cada educacion", fontsize=18, fontweight='bold')
plt.xticks(rotation=70)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado una observación relevante basada en los datos representados:
#
# Si tienes un doctorado, una maestría, una escuela profesional o una licenciatura, tienes una alta probabilidad de ganar más de 50K al año. Esta relación positiva sugiere que un nivel educativo más avanzado está asociado con mayores probabilidades de alcanzar ingresos superiores a 50K anuales.
#
# Estas observaciónes subrayan la importancia de la educación en la determinación de los ingresos y destaca cómo diferentes niveles educativos pueden impactar significativamente las oportunidades laborales y los salarios.

# %% [markdown]
# ### ⇨ Estado civil

# %%
# Indicando el tamaño del marco
fig, ax = plt.subplots(figsize=(15, 4))

# Creando groupby para generar el gráfico
estado_civil_y = adultos.groupby(['estado_civil', '>50K']).size().unstack(fill_value=0).reset_index()
estado_civil_y = estado_civil_y.rename(columns={0: '<=50K', 1: '>50K'})

# Cambiándolo de formato
estado_civil_y_long = estado_civil_y.melt(id_vars='estado_civil', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# Creando el gráfico
sns.barplot(data=estado_civil_y_long, x='estado_civil', y='value', hue='variables', palette='Blues_r')

# Configurando títulos y variables
plt.title('Conteo de ingresos por estado civil', fontsize = 18, fontweight = 'bold')
plt.xlabel('Estado Civil')
plt.ylabel('Ganancias por personas')
plt.xticks(rotation=75)

# Añadir etiquetas de datos a cada barra
for p in ax.patches:
    ax.annotate(str(p.get_height()),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points',
                fontsize=8)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones interesantes basadas en los datos presentados:
#
# 1.   Las personas casadas muestran una alta probabilidad de tener ingresos más altos (posiblemente relacionado con la edad), y esta tendencia también se observa en los divorciados y viudos, quienes también presentan niveles significativos de ingresos superiores a 50K al año.
# 2.   Por otro lado, los solteros no parecen tener muchas posibilidades de alcanzar ingresos superiores a 50K al año, ya que su presencia en esta categoría de ingresos es menor en comparación con los grupos de personas casadas, divorciadas y viudas.
#
# Estas observaciones sugieren que el estado civil puede estar relacionado con los ingresos y que las personas casadas, divorciadas y viudas parecen tener una mayor probabilidad de alcanzar ingresos más altos en comparación con los solteros.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
# Calculando las probabilidades
estado_civil_y['total_estado_civil'] = estado_civil_y['<=50K'] + estado_civil_y['>50K']
estado_civil_y['probabilidad_>50K'] = ((estado_civil_y['>50K'] / estado_civil_y['total_estado_civil']) * 100).round(2)
estado_civil_y['probabilidad_<=50K'] = ((estado_civil_y['<=50K'] / estado_civil_y['total_estado_civil']) * 100).round(2)

# Convirtiendo a formato float
estado_civil_y['probabilidad_>50K'] = estado_civil_y['probabilidad_>50K'].astype(float)
estado_civil_y['probabilidad_<=50K'] = estado_civil_y['probabilidad_<=50K'].astype(float)

estado_civil_y
# Out:
# >50K                           estado_civil  <=50K  >50K  total_estado_civil  \
# 0                Casado/a - Conyuge ausente    384    34                 418
# 1     Casado/a - Conyuge en la Fuerza Aérea     13    10                  23
# 2                  Casado/a - Cónyuge civil   8284  6692               14976
# 3                              Divorciado/a   3980   463                4443
# 4                                Separado/a    959    66                1025
# 5                                 Soltero/a  10192   491               10683
# 6                                   Viudo/a    908    85                 993
#
# >50K  probabilidad_>50K  probabilidad_<=50K
# 0                  8.13               91.87
# 1                 43.48               56.52
# 2                 44.68               55.32
# 3                 10.42               89.58
# 4                  6.44               93.56
# 5                  4.60               95.40
# ...

# %%
# Agrupar los datos por la columna "estado_civil" y calcular la suma de las columnas de porcentaje
grouped_data = estado_civil_y.groupby("estado_civil").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_>50K", "probabilidad_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax = plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro del estado civil")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro del estado civil")

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Estado Civil")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar más de 50K de cada estado civil", fontsize=18, fontweight='bold')
plt.legend()
plt.xticks(rotation=75)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones importantes basadas en los datos presentados:
#
# 1.   En general, las personas casadas tienen bastantes posibilidades de alcanzar ingresos superiores a 50K al año, lo que sugiere una correlación positiva entre el estado civil de estar casado y mayores ingresos.
# 2.   Sin embargo, esta tendencia cambia drásticamente en el caso de las personas casadas o con cónyuge ausente. En este grupo específico, las posibilidades de alcanzar ingresos más altos disminuyen significativamente.
#
# Estas observaciones resaltan la importancia de considerar el estado civil específico al analizar los ingresos y sugieren que el impacto del estado civil en los ingresos puede variar dependiendo de si la persona está casada o tiene el cónyuge ausente.

# %% [markdown]
# ### ⇨ Clase de trabajo

# %%
# Indicando el tamaño del marco
fig, ax = plt.subplots(figsize=(15, 4))

# Creando groupby para generar el gráfico
clase_trabajo_y = adultos.groupby(['clase_trabajo', '>50K']).size().unstack(fill_value=0).reset_index()
clase_trabajo_y = clase_trabajo_y.rename(columns={0: '<=50K', 1: '>50K'})

# Cambiándolo de formato
clase_trabajo_y_long = clase_trabajo_y.melt(id_vars='clase_trabajo', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# Creando el gráfico
sns.barplot(data=clase_trabajo_y_long, x='clase_trabajo', y='value', hue='variables', palette='Blues_r')

# Configurando títulos y variables
plt.title('Conteo de ingresos por clase de trabajo', fontsize = 18, fontweight = 'bold')
plt.xlabel('Clase de Trabajo')
plt.ylabel('Ganancias por personas')
plt.xticks(rotation=75)

# Añadir etiquetas de datos a cada barra
for p in ax.patches:
    ax.annotate(str(p.get_height()),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points',
                fontsize=8)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones significativas basadas en los datos presentados:
#
# 1.   Las personas autónomas con incorporación parecen tener aún más posibilidades de alcanzar ingresos superiores a 50K al año que las personas sin incorporación. Esto sugiere que la incorporación puede estar relacionada con un aumento en las oportunidades de mayores ingresos.
# 2.   En cuanto a las personas sin remuneración y aquellas que nunca han trabajado, los datos indican que es recomendable que busquen un empleo o, si ya tienen uno, consideren oportunidades laborales que les permitan obtener un mejor ingreso. Esto sugiere que estas dos categorías pueden estar asociadas con menores probabilidades de alcanzar ingresos más altos.
#
# Estas observaciones resaltan la importancia de considerar el tipo de empleo y la experiencia laboral al analizar las posibilidades de ingresos superiores a 50K al año.

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
# Calculando las probabilidades
clase_trabajo_y['total_clase_trabajo'] = clase_trabajo_y['<=50K'] + clase_trabajo_y['>50K']
clase_trabajo_y['probabilidad_>50K'] = ((clase_trabajo_y['>50K'] / clase_trabajo_y['total_clase_trabajo']) * 100).round(2)
clase_trabajo_y['probabilidad_<=50K'] = ((clase_trabajo_y['<=50K'] / clase_trabajo_y['total_clase_trabajo']) * 100).round(2)

# Convirtiendo a formato float
clase_trabajo_y['probabilidad_>50K'] = clase_trabajo_y['probabilidad_>50K'].astype(float)
clase_trabajo_y['probabilidad_<=50K'] = clase_trabajo_y['probabilidad_<=50K'].astype(float)

clase_trabajo_y
# Out:
# >50K               clase_trabajo  <=50K  >50K  total_clase_trabajo  \
# 0     Autonomo con incorporacion    494   622                 1116
# 1     Autonomo sin incorporacion   1817   724                 2541
# 2               Gobierno estatal    945   353                 1298
# 3               Gobierno federal    589   371                  960
# 4                 Gobierno local   1476   617                 2093
# 5             Nunca ha trabajado      7     0                    7
# 6                        Privado  17733  4963                22696
# 7               Sin remuneracion     14     0                   14
#
# >50K  probabilidad_>50K  probabilidad_<=50K
# 0                 55.73               44.27
# 1                 28.49               71.51
# 2                 27.20               72.80
# 3                 38.65               61.35
# 4                 29.48               70.52
# 5                  0.00              100.00
# 6                 21.87               78.13
# ...

# %%
# Agrupar los datos por la columna "clase_trabajo" y calcular la suma de las columnas de porcentaje
grouped_data = clase_trabajo_y.groupby("clase_trabajo").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_>50K", "probabilidad_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax = plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro de la Clase de Trabajo")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro de la Clase de Trabajo")

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Clase de Trabajo")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar más de 50K de cada clase de trabajo", fontsize=18, fontweight='bold')
plt.legend()
plt.xticks(rotation=75)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones importantes basadas en los datos presentados:
#
# 1.   Las personas que trabajan para gobiernos y las personas autónomas con incorporación tienen las posibilidades más altas de alcanzar ingresos superiores a 50K al año. Esto sugiere que estos grupos ocupacionales pueden estar asociados con oportunidades laborales que ofrecen mayores ingresos.
# 2.   Por otro lado, las personas que nunca han trabajado y las que no reciben remuneración no muestran posibilidades de alcanzar ingresos superiores a 50K al año. Esto indica que estas dos categorías pueden estar relacionadas con menores probabilidades de obtener mayores ingresos.
#
# Estas observaciones resaltan la importancia de considerar el tipo de empleo o la actividad laboral al analizar las posibilidades de ingresos superiores a 50K al año.

# %% [markdown]
# ### ⇨ Relación

# %%
# Indicando el tamaño del marco
fig, ax = plt.subplots(figsize=(15, 4))

# Creando groupby para generar el gráfico
relacion_y = adultos.groupby(['relacion', '>50K']).size().unstack(fill_value=0).reset_index()
relacion_y = relacion_y.rename(columns={0: '<=50K', 1: '>50K'})

# Cambiándolo de formato
relacion_y_long = relacion_y.melt(id_vars='relacion', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# Creando el gráfico
sns.barplot(data=relacion_y_long, x='relacion', y='value', hue='variables', palette='Blues_r')

# Configurando títulos y variables
plt.title('Conteo de ingresos por relación', fontsize = 18, fontweight = 'bold')
plt.xlabel('Relación')
plt.ylabel('Ganancias por personas')
plt.xticks(rotation=75)

# Añadir etiquetas de datos a cada barra
for p in ax.patches:
    ax.annotate(str(p.get_height()),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points',
                fontsize=8)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones basadas en los datos presentados:
#
# 1.   Los esposos presentan bastantes posibilidades de ganar más dinero, lo que sugiere una correlación positiva entre el estado de ser esposo y mayores ingresos.
# 2.   Por otro lado, los demás parientes (otros parientes) no tienen oportunidades significativas de alcanzar mayores ingresos, lo que indica que esta categoría puede estar relacionada con menores probabilidades de obtener mayores ingresos.
#
# Estas observaciones resaltan la importancia de considerar la relación específica entre el estado de ser esposo y los ingresos, y cómo los demás parientes no parecen tener oportunidades significativas de alcanzar ingresos más altos.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
# Calculando las probabilidades
relacion_y['total_relacion'] = relacion_y['<=50K'] + relacion_y['>50K']
relacion_y['probabilidad_>50K'] = ((relacion_y['>50K'] / relacion_y['total_relacion']) * 100).round(2)
relacion_y['probabilidad_<=50K'] = ((relacion_y['<=50K'] / relacion_y['total_relacion']) * 100).round(2)

# Convirtiendo a formato float
relacion_y['probabilidad_>50K'] = relacion_y['probabilidad_>50K'].astype(float)
relacion_y['probabilidad_<=50K'] = relacion_y['probabilidad_<=50K'].astype(float)

relacion_y
# Out:
# >50K          relacion  <=50K  >50K  total_relacion  probabilidad_>50K  \
# 0               Esposa    823   745            1568              47.51
# 1               Esposo   7275  5918           13193              44.86
# 2      Hijo/a propio/a   5001    67            5068               1.32
# 3     No en la familia   7449   856            8305              10.31
# 4        Otro pariente    944    37             981               3.77
# 5            Soltero/a   3228   218            3446               6.33
#
# >50K  probabilidad_<=50K
# 0                  52.49
# 1                  55.14
# 2                  98.68
# 3                  89.69
# 4                  96.23
# 5                  93.67

# %%
# Agrupar los datos por la columna "relacion" y calcular la suma de las columnas de porcentaje
grouped_data = relacion_y.groupby("relacion").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_>50K", "probabilidad_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax = plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro de la relación")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro de la relación")

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Relación")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar más de 50K de cada relación", fontsize=18, fontweight='bold')
plt.legend()
plt.xticks(rotation=75)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones basadas en los datos presentados:
#
# 1.   Ser esposo o esposa parece estar asociado con mayores posibilidades de ganar más de 50K al año, lo que sugiere una correlación positiva entre el estado civil de casado y mayores ingresos.
# 2.   Por otro lado, las hijas o hijos propios tienen muy bajas posibilidades de ganar más de 50K al año. Esto podría deberse al hecho de que estas personas pueden ser menores de edad y, por lo tanto, no están trabajando o no han alcanzado ingresos significativos en el momento de la recopilación de datos.
#
# Estas observaciones resaltan la importancia de considerar el estado civil específico y la edad al analizar las posibilidades de ingresos superiores a 50K al año.

# %% [markdown]
# ### ⇨ Raza

# %%
# groupby para ordenar los datos en base a la variable y
raza_y = adultos.groupby(['raza', 'ingreso_y']).size().unstack(fill_value=0).reset_index()
raza_y = raza_y.rename(columns={0: '<=50K', 1: '>50K'})

# Reorganizar los datos en formato largo (long format)
raza_y = raza_y.melt(id_vars='raza', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# creando el grafico
sns.barplot(data=raza_y, x='raza', y='value', hue='variables', palette='Blues_r')

#configuar titulos y leyendas
plt.title('Conteo de ingresos por raza y color de piel', fontsize = 18, fontweight = 'bold')
plt.xlabel('Raza')
plt.ylabel('Personas -50K vs +50K')
plt.xticks(rotation=60)

for p in ax.patches:
    ax.annotate(str(p.get_height()),  # Convertir el valor entero a una cadena
                (p.get_x() + p.get_width() / 2, p.get_height()),  # Posición de la etiqueta
                ha='center', va='center',  # Alineación horizontal y vertical de la etiqueta
                xytext=(0, 5),  # Desplazamiento de la etiqueta (opcional)
                textcoords='offset points',  # Coordenadas de desplazamiento relativas
                fontsize=8)  # Tamaño de fuente de la etiqueta (opcional)
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Una observación importante a notar aquí es que, a excepción de las personas blancas, hay muy pocas representaciones de diferentes razas en los datos. Debido a esta falta de diversidad racial en la muestra, es posible que no se tenga una comprensión precisa del porcentaje y la relación de personas de diferentes razas que ganan más de 50,000 dólares al año.
#
# Esta falta de representación puede sesgar el análisis y las conclusiones, ya que las diferencias socioeconómicas y de oportunidades laborales entre diferentes grupos raciales pueden ser significativas. Para obtener una imagen más completa y precisa, es fundamental tener una muestra diversa y representativa de todas las razas y grupos étnicos.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
#creando groupby necesario
raza_y = adultos.groupby(['raza', '>50K']).size().unstack(fill_value=0).reset_index()
raza_y = raza_y.rename(columns={0: '<=50K', 1: '>50K'})

#calculo de las probabilidades
raza_y['total_raza'] = raza_y['<=50K'] + raza_y['>50K']
raza_y['probabilidad_raza_>50K'] = ((raza_y['>50K'] / raza_y['total_raza']) * 100).round(2)
raza_y['probabilidad_raza_<=50K'] = ((raza_y['<=50K'] / raza_y['total_raza']) * 100).round(2)

#cambiando formato a float de las nuevas columnas
raza_y['probabilidad_raza_>50K'] = raza_y['probabilidad_raza_>50K'].astype(float)
raza_y['probabilidad_raza_<=50K'] = raza_y['probabilidad_raza_<=50K'].astype(float)

raza_y
# Out:
# >50K                                raza  <=50K  >50K  total_raza  \
# 0     Asiático de las Islas del Pacífico    763   276        1039
# 1                                 Blanco  20699  7117       27816
# 2             Indio Americano / Esquimal    275    36         311
# 3                                  Negro   2737   387        3124
# 4                                   Otro    246    25         271
#
# >50K  probabilidad_raza_>50K  probabilidad_raza_<=50K
# 0                      26.56                    73.44
# 1                      25.59                    74.41
# 2                      11.58                    88.42
# 3                      12.39                    87.61
# 4                       9.23                    90.77

# %%
# Agrupar los datos por la columna "trabajo" y calcular la suma de las columnas de porcentaje
grouped_data = raza_y.groupby("raza").sum()

# definiendo parametros
categorias = grouped_data.index
columnas = ["probabilidad_raza_>50K", "probabilidad_raza_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax =  plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro dentro de la raza")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro de la raza")

# Agregar etiquetas de datos a cada barra con el signo de porcentaje
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_apilada_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Raza")
plt.ylabel("Probabilidad")
plt.title("Probabilidad de ganar mas de 50K de cada raza", fontsize=18, fontweight='bold')
plt.legend()
plt.xticks(rotation=75)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')


# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones relevantes basadas en los datos presentados:
#
# 1.   Los asiáticos de las islas del Pacífico encabezan la lista con un 26,56% de probabilidades de ganar más de 50K al año. Esto indica que este grupo racial tiene la mayor probabilidad de tener ingresos superiores a 50,000 dólares anuales en comparación con otros grupos raciales en el conjunto de datos.
# 2.   Los blancos ocupan el segundo lugar en la lista con una probabilidad del 25,59% de ganar más de 50K al año. Si bien tienen una alta probabilidad de mayores ingresos, es ligeramente inferior a la de los asiáticos de las islas del Pacífico.
#
# Estas observaciones destacan las diferencias en las probabilidades de ingresos entre diferentes grupos raciales y resaltan cómo los asiáticos de las islas del Pacífico tienen la mayor probabilidad, seguidos por los blancos en la muestra de datos.

# %% [markdown]
# ### ⇨ Sexo

# %%
# Indicando el tamaño del marco
fig, ax = plt.subplots(figsize=(15, 4))

# Creando groupby para generar el gráfico
sexo_y = adultos.groupby(['sexo', '>50K']).size().unstack(fill_value=0).reset_index()
sexo_y = sexo_y.rename(columns={0: '<=50K', 1: '>50K'})

# Cambiándolo de formato
sexo_y_long = sexo_y.melt(id_vars='sexo', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# Configurando los colores de las barras
colores = ['#FF0000', '#0000FF']  # Rojo y azul

# Creando el gráfico
sns.barplot(data=sexo_y_long, x='sexo', y='value', hue='variables', palette='Blues_r')

# Configurando títulos y variables
plt.title('Conteo de ingresos por sexo', fontsize = 18, fontweight = 'bold')
plt.xlabel('Sexo')
plt.ylabel('Ganancias por personas')

# Añadir etiquetas de datos a cada barra
for p in ax.patches:
    ax.annotate(str(p.get_height()),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points',
                fontsize=8)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones importantes basadas en los datos presentados:
#
# 1.   Se observa una disparidad en las posibilidades entre hombres y mujeres. Los hombres parecen tener mayores probabilidades de ganar más de 50K al año en comparación con las mujeres. Esto sugiere que puede existir un sesgo o desigualdad de género en cuanto a los ingresos, donde los hombres tienen mayores oportunidades de alcanzar ingresos superiores.
# 2.   Por otro lado, las mujeres enfrentan un tema de menos salario, ya que sus posibilidades de ganar más de 50K al año parecen ser menores en la muestra de datos. Esto indica que las mujeres pueden enfrentar barreras o desafíos en el ámbito laboral que impactan negativamente en sus ingresos.
#
# Estas observaciones resaltan la importancia de abordar la equidad de género en el ámbito laboral y la necesidad de tomar medidas para reducir las disparidades salariales entre hombres y mujeres.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
# Calculando las probabilidades
sexo_y['total_sexo'] = sexo_y['<=50K'] + sexo_y['>50K']
sexo_y['probabilidad_>50K'] = ((sexo_y['>50K'] / sexo_y['total_sexo']) * 100).round(2)
sexo_y['probabilidad_<=50K'] = ((sexo_y['<=50K'] / sexo_y['total_sexo']) * 100).round(2)

# Convirtiendo a formato float
sexo_y['probabilidad_>50K'] = sexo_y['probabilidad_>50K'].astype(float)
sexo_y['probabilidad_<=50K'] = sexo_y['probabilidad_<=50K'].astype(float)

sexo_y
# Out:
# >50K       sexo  <=50K  >50K  total_sexo  probabilidad_>50K  \
# 0      Femenino   9592  1179       10771              10.95
# 1     Masculino  15128  6662       21790              30.57
#
# >50K  probabilidad_<=50K
# 0                  89.05
# 1                  69.43

# %%
# Agrupar los datos por la columna "estado_civil" y calcular la suma de las columnas de porcentaje
grouped_data = sexo_y.groupby("sexo").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_>50K", "probabilidad_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax = plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro del sexo")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro del sexo")

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Sexo")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar más de 50K de cada sexo")
plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado una observación importante basada en los datos presentados:
#
# *   Siendo hombre, tienes mayores posibilidades de ganar más de 50K al año en comparación con las mujeres. Esto sugiere que existe una diferencia significativa en las oportunidades de ingresos entre hombres y mujeres en el conjunto de datos analizado.
#
# Esta observación resalta la presencia de una posible desigualdad de género en el ámbito salarial, donde los hombres tienen mayores probabilidades de alcanzar ingresos superiores a 50K al año en comparación con las mujeres.

# %% [markdown]
# ### ⇨ Trabajo

# %%
# indicando el tamano del marco
fig, ax =  plt.subplots(figsize=(15, 4))

# creando groupby para generar el grafico
trabajo_y = adultos.groupby(['trabajo', '>50K']).size().unstack(fill_value=0).reset_index()
trabajo_y = trabajo_y.rename(columns={0: '<=50K', 1: '>50K'})

# cambiandolo de formato
trabajo_y_long = trabajo_y.melt(id_vars='trabajo', value_vars=['<=50K', '>50K'], var_name='variables').sort_values('value', ascending=False)

# Configurando los colores de las barras
colores = ['#FF0000', '#0000FF']  # Rojo y azul

# creando el grafico
sns.barplot(data=trabajo_y_long, x='trabajo', y='value', hue='variables', palette='Blues_r')

# configurando titulos y variables
plt.title('Conteo de ingresos por trabajo', fontsize = 18, fontweight = 'bold')
plt.xlabel('Trabajo')
plt.ylabel('Ganancias por personas')
plt.xticks(rotation=75)

# Añadir etiquetas de datos a cada barra
for p in ax.patches:
    ax.annotate(str(p.get_height()),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='center',
                xytext=(0, 5),
                textcoords='offset points',
                fontsize=8)

plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado dos observaciones relevantes basadas en los datos presentados:
#
# 1.   Los directores ejecutivos parecen tener bastantes posibilidades de ganar más de 50K al año, y esto es bastante lógico debido a la naturaleza de sus puestos de alto nivel en las organizaciones. Estos roles de liderazgo suelen estar asociados con salarios más altos y, por lo tanto, es comprensible que tengan mayores probabilidades de alcanzar ingresos superiores.
# 2.   Además, los especialistas profesionales también tienen muchas posibilidades de ganar más de 50K al año. Esta categoría de trabajadores, que incluye a personas con habilidades y conocimientos especializados en áreas específicas, también puede beneficiarse de salarios competitivos debido a la demanda de sus habilidades únicas.
#
# Estas observaciones destacan cómo los roles de liderazgo como los directores ejecutivos y las habilidades especializadas de los profesionales pueden influir en las oportunidades de ingresos superiores.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Análisis de Porcentajes**
#
# En este estudio, analizaremos las probabilidades que tiene cada variable de esta columna para ganar más o menos de 50,000 dólares al año.

# %%
# calculando las probabilidades
trabajo_y['total_trabajo'] = trabajo_y['<=50K'] + trabajo_y['>50K']
trabajo_y['probabilidad_trabajo_>50K'] = ((trabajo_y['>50K'] / trabajo_y['total_trabajo']) * 100).round(2)
trabajo_y['probabilidad_trabajo_<=50K'] = ((trabajo_y['<=50K'] / trabajo_y['total_trabajo']) * 100).round(2)

#conviertiendo a formato float
trabajo_y['probabilidad_trabajo_>50K'] = trabajo_y['probabilidad_trabajo_>50K'].astype(float)
trabajo_y['probabilidad_trabajo_<=50K'] = trabajo_y['probabilidad_trabajo_<=50K'].astype(float)

trabajo_y
# Out:
# >50K                           trabajo  <=50K  >50K  total_trabajo  \
# 0          Administrativo y de oficina   3263   507           3770
# 1                  Agricultura y pesca    879   115            994
# 2                Artesano y reparación   3170   929           4099
# 3                  Directivo ejecutivo   2098  1968           4066
# 4             Especialista profesional   2281  1859           4140
# 5                      Fuerzas Armadas      8     1              9
# 6          Manipuladores y limpiadores   1284    86           1370
# 7     Operador de maquinas e inspector   1752   250           2002
# 8                      Otros servicios   3158   137           3295
# 9           Servicio domestico privado    148     1            149
# 10             Servicios de proteccion    438   211            649
# 11                     Soporte tecnico    645   283            928
# 12             Transporte y movimiento   1277   320           1597
# ...

# %%
# Agrupar los datos por la columna "trabajo" y calcular la suma de las columnas de porcentaje
grouped_data = trabajo_y.groupby("trabajo").sum()

# Obtener las categorías y las columnas de porcentaje
categorias = grouped_data.index
columnas = ["probabilidad_trabajo_>50K", "probabilidad_trabajo_<=50K"]

# Configurar los datos para cada columna
datos_columnas = [grouped_data[col] for col in columnas]

# Crear el gráfico de columnas apiladas
fig, ax =  plt.subplots(figsize=(15, 4))
plt.bar(categorias, datos_columnas[0], label="Probabilidad de ganar más de 50K dentro del trabajo")
plt.bar(categorias, datos_columnas[1], bottom=datos_columnas[0], label="Probabilidad de ganar menos o igual de 50K dentro del trabajo")

# Agregar etiquetas de datos a cada barra
for i in range(len(categorias)):
    x = categorias[i]
    y1 = datos_columnas[0][i]
    y2 = datos_columnas[1][i]
    if columnas[1] == "probabilidad_trabajo_<=50K":
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center', color='white')
    else:
        plt.text(x, y1/2, f"{y1:.2f}%", ha='center', va='center')
        plt.text(x, y1 + y2/2, f"{y2:.2f}%", ha='center', va='center')

# Configurar etiquetas y leyendas
plt.xlabel("Trabajo")
plt.ylabel("Porcentaje")
plt.title("Probabilidad de ganar mas de 50K de cada trabajo")
plt.legend()
plt.xticks(rotation=75)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Análisis del Gráfico**
#
# Hemos realizado cuatro observaciones basadas en los datos presentados:
#
# 1.   Los directores ejecutivos son quienes tienen la mayor probabilidad de ganar más de 50K al año, con un 48,40% de probabilidades. Esto se debe a la naturaleza de sus puestos de alto nivel, que generalmente están asociados con salarios significativamente más altos.
# 2.   Los especialistas profesionales ocupan el segundo lugar en la lista, con un 44,90% de probabilidades de ganar más de 50K al año. Esta categoría de trabajadores con habilidades especializadas y conocimientos técnicos también goza de salarios competitivos debido a la demanda de sus habilidades.
# 3.   Por otro lado, los trabajadores de servicio doméstico privado tienen la menor probabilidad de ganar más de 50K al año, con solo un 0,67% de probabilidades. Esta categoría de empleo generalmente implica trabajos de baja remuneración.
# 4.   Los manipuladores y limpiadores ocupan el segundo lugar en la lista de menor probabilidad (además de otros), con un 6,28% de probabilidades de ganar más de 50K al año. Esta categoría también puede involucrar trabajos con salarios más bajos.
#
# Estas observaciones resaltan las diferencias en las probabilidades de ingresos entre diferentes categorías de empleo y cómo ciertos trabajos, como los de directores ejecutivos y especialistas profesionales, tienen mayores posibilidades de ingresos más altos en comparación con otros empleos, como los de servicio doméstico privado y manipuladores y limpiadores.

# %% [markdown]
# ## d➝ **Graficos multivariados**

# %% [markdown]
# ### ⇨ Mapa de calor correlacion variables numericas

# %%
# anadir variables en mapa
adultos_mapa = adultos.copy()
adultos_mapa['ingreso_y']= adultos_mapa['ingreso_y'].map({'<=50K': 0, '>50K': 1})

# tamano
plt.figure(figsize = (12,10))

# grafico
sns.heatmap(adultos_mapa.corr(), cmap = 'Blues_r', annot = True)

# leyendas y titulos
plt.title("Correlación entre diferentes variabless del conjunto de datos", fontsize = 18, fontweight = 'bold')
plt.xticks(fontsize=12, rotation = 75)
plt.legend(fontsize=12)

plt.show()
# Out:
# <ipython-input-49-486f8fa2625a>:9: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(adultos_mapa.corr(), cmap = 'Blues_r', annot = True)
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Analisis del Gráfico**
#
# En este análisis, hemos creado exitosamente un mapa de correlación para determinar las relaciones entre las características independientes y la variable dependiente.
#
# Observamos que la mayoría de las características muestran una correlación positiva con las dos variables de "ingreso_y". Esto sugiere que estas características tienen una influencia significativa en la variable objetivo y pueden ser predictivas de mayores ingresos.
#
# Sin embargo, es importante mencionar que este gráfico de correlación no incluye las relaciones con variables categóricas o de etiquetas. Para obtener una imagen más completa, sería necesario realizar un análisis de correlación específico para estas variables y evaluar su impacto en el resultado general.
#
# En general, este mapa de correlación proporciona una visión valiosa de las relaciones lineales entre las características numéricas y la variable de interés, pero se deben realizar análisis adicionales para considerar otras variables relevantes.

# %%
adultos.head(1)
# Out:
#    edad clase_trabajo  fnlwgt                       educacion  educacion_num  \
# 0    90           NaN   77053  Graduado de escuela secundaria              9
#
#   estado_civil trabajo          relacion    raza      sexo  plusvalia  \
# 0      Viudo/a     NaN  No en la familia  Blanco  Femenino          0
#
#    perdida_capital  horas_trabajo_semanal     pais_nativo ingreso_y  <=50K  \
# 0             4356                     40  Estados Unidos     <=50K      1
#
#    >50K categoria_edad
# 0     0   Mayor que 70

# %%
razas_count = adultos.groupby('raza').educacion.count()
razas_count
# Out:
# raza
# Asiático de las Islas del Pacífico     1039
# Blanco                                27816
# Indio Americano / Esquimal              311
# Negro                                  3124
# Otro                                    271
# Name: educacion, dtype: int64

# %%
len(adultos)
# Out:
# 32561

# %% [markdown]
# # **5. Selección de características (feature selection)**
#
# Esta sección tiene como objetivo reducir la dimensionalidad del dataset, con la intención de eliminar aquellas columnas que no son relevantes para el análisis.

# %% [markdown]
# En base al análisis, las únicas columnas que se decidieron eliminar fueron:
#
# 1.   fnlwgt
# 2.   educacion_num
# 3.   <=50K
# 4.   categoria_edad
# 5.   ingreso_y
#
# Razones:
#
# *   La columna "fnlwgt" muestra una correlación casi nula con la variable objetivo (y).
# *   La columna "educacion_num" es redundante, ya que es equivalente a la variable categórica "educacion".
# *   La columna "<=50K" representa lo mismo que su columna opuesta, por lo que también fue eliminada.

# %%
# creando copia para ajustar en un futuro
adultos_norm = adultos.copy()

# %%
# eliminando las columnas
adultos_norm = adultos_norm.drop(['fnlwgt', 'educacion_num', '<=50K', 'categoria_edad', 'ingreso_y'], axis=1)

# %%
# cambiando nommbre de columna y
adultos_norm = adultos_norm.rename(columns={'>50K':'y'})

# %%
# mostrando dataframe
adultos_norm.head(3)
# Out:
#    edad clase_trabajo                       educacion estado_civil  \
# 0    90           NaN  Graduado de escuela secundaria      Viudo/a
# 1    82       Privado  Graduado de escuela secundaria      Viudo/a
# 2    66           NaN             Algo de universidad      Viudo/a
#
#                trabajo          relacion    raza      sexo  plusvalia  \
# 0                  NaN  No en la familia  Blanco  Femenino          0
# 1  Directivo ejecutivo  No en la familia  Blanco  Femenino          0
# 2                  NaN         Soltero/a   Negro  Femenino          0
#
#    perdida_capital  horas_trabajo_semanal     pais_nativo  y
# 0             4356                     40  Estados Unidos  0
# 1             4356                     18  Estados Unidos  0
# 2             4356                     40  Estados Unidos  0

# %% [markdown]
# # **6. Algoritmos de clasificación**
#
# Estamos desarrollando un algoritmo de clasificación con el objetivo de predecir de manera altamente precisa nuestra variable dependiente.

# %% [markdown]
# ## a➝ **Preparando el dataframe**
#
# Estamos realizando ajustes en cada columna de los datos con el objetivo de asegurar que no se presenten errores al crear el modelo.

# %%
# ajustando todas las columnas
adultos_norm['clase_trabajo'] = adultos_norm['clase_trabajo'].replace({np.nan: 0,
                                                                       'Privado':1,
                                                                       'Gobierno estatal': 2,
                                                                       'Gobierno federal': 3,
                                                                       'Autonomo sin incorporacion': 4,
                                                                       'Autonomo con incorporacion': 5,
                                                                       'Gobierno local': 6,
                                                                       'Sin remuneracion': 7,
                                                                       'Nunca ha trabajado': 8})

adultos_norm['educacion'] = adultos_norm['educacion'].replace({'Graduado de escuela secundaria': 0,
                                                               'Algo de universidad': 1,
                                                               'Escuela': 2,
                                                               'Doctorado': 3,
                                                               'Escuela profesional': 4,
                                                               'Licenciatura': 5,
                                                               'Maestria': 6,
                                                               'Asociado - Administracion': 7,
                                                               'Asociado - Vocacional': 8})

adultos_norm['estado_civil'] = adultos_norm['estado_civil'].replace({'Viudo/a': 0,
                                                                     'Divorciado/a': 1,
                                                                     'Separado/a': 2,
                                                                     'Soltero/a': 3,
                                                                     'Casado/a - Cónyuge civil': 4,
                                                                     'Casado/a - Conyuge ausente': 5,
                                                                     'Casado/a - Conyuge en la Fuerza Aérea': 6})

adultos_norm['trabajo'] = adultos_norm['trabajo'].replace({np.nan: 0,
                                                           'Directivo ejecutivo': 1,
                                                           'Operador de maquinas e inspector': 2,
                                                           'Especialista profesional': 3,
                                                           'Otros servicios': 4,
                                                           'Administrativo y de oficina': 5,
                                                           'Artesano y reparación': 6,
                                                           'Transporte y movimiento': 7,
                                                           'Manipuladores y limpiadores': 8,
                                                           'Ventas': 9,
                                                           'Agricultura y pesca': 10,
                                                           'Soporte tecnico': 11,
                                                           'Servicios de proteccion': 12,
                                                           'Fuerzas Armadas': 13,
                                                           'Servicio domestico privado': 14})

adultos_norm['relacion'] = adultos_norm['relacion'].replace({'No en la familia': 0,
                                                             'Soltero/a': 1,
                                                             'Hijo/a propio/a': 2,
                                                             'Otro pariente': 3,
                                                             'Esposo': 4,
                                                             'Esposa': 5})

adultos_norm['raza'] = adultos_norm['raza'].replace({'Blanco': 0,
                                                     'Negro': 1,
                                                     'Asiático de las Islas del Pacífico': 2,
                                                     'Otro': 3,
                                                     'Indio Americano / Esquimal': 4})

adultos_norm['sexo'] = adultos_norm['sexo'].replace({'Femenino': 0,
                                                     'Masculino': 1})

adultos_norm['pais_nativo'] = adultos_norm['pais_nativo'].replace({np.nan: 0,
                                                                   'Mexico': 1,
                                                                   'Grecia': 2,
                                                                   'Vietnam': 3,
                                                                   'China': 4,
                                                                   'Taiwan': 5,
                                                                   'India': 6,
                                                                   'Filipinas': 7,
                                                                   'Trinidad y Tobago': 8,
                                                                   'Canada': 9,
                                                                   'Sur': 10,
                                                                   'Paises Bajos': 11,
                                                                   'Puerto Rico': 12,
                                                                   'Polonia': 13,
                                                                   'Irán': 14,
                                                                   'Inglaterra': 15,
                                                                   'Alemania': 16,
                                                                   'Italia': 17,
                                                                   'Japón': 18,
                                                                   'Hong Kong': 19,
                                                                   'Honduras': 20,
                                                                   'Cuba': 21,
                                                                   'Irlanda': 22,
                                                                   'Camboya': 23,
                                                                   'Perú': 24,
                                                                   'Nicaragua': 25,
                                                                   'Republica Dominicana': 26,
                                                                   'Haiti': 27,
                                                                   'El Salvador': 28,
                                                                   'Hungria': 29,
                                                                   'Colombia': 30,
                                                                   'Guatemala': 31,
                                                                   'Jamaica': 32,
                                                                   'Ecuador': 33,
                                                                   'Francia': 34,
                                                                   'Yugoslavia': 35,
                                                                   'Escocia': 36,
                                                                   'Portugal': 37,
                                                                   'Laos': 38,
                                                                   'Tailandia': 39,
                                                                   'Territorios Exteriores de EE. UU.': 40,
                                                                   'Estados Unidos': 41})


### ACTIVAR LABEL ENCODING

# %%
# mostando dataframe ajustado
adultos_norm.head(5)
# Out:
#    edad  clase_trabajo  educacion  estado_civil  trabajo  relacion  raza  \
# 0    90              0          0             0        0         0     0
# 1    82              1          0             0        1         0     0
# 2    66              0          1             0        0         1     1
# 3    54              1          2             1        2         1     0
# 4    41              1          1             2        3         2     0
#
#    sexo  plusvalia  perdida_capital  horas_trabajo_semanal  pais_nativo  y
# 0     0          0             4356                     40           41  0
# 1     0          0             4356                     18           41  0
# 2     0          0             4356                     40           41  0
# 3     0          0             3900                     40           41  0
# 4     0          0             3900                     40           41  0

# %% [markdown]
# En esta etapa, he decidido realizar ajustes en los dataframes mediante la conversión de variables numéricas, con el fin de adecuarlos al modelo de datos.

# %% [markdown]
# ## b➝ **Importando librerias necesarias y creando variables de entrenamiento y testeo**

# %%
# importando modelos de aprendizaje
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
import lightgbm as lgb
from sklearn.svm import SVC

# %%
# importando funcion para testeo
from sklearn.model_selection import train_test_split

# %%
# importando metricas para evaluacion de modelos
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
# creacion de variables de entrenamiento y testeo
X = adultos_norm.iloc[:, :-1]
y = adultos_norm['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# ## d➝ **Random forest**

# %%
# generando y entrenando modelo
modelo_rfc = RandomForestClassifier()
modelo_rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# prediciendo
pred_rfc = modelo_rfc.predict(X_test)

# %%
print('El accuracy del random forest es: ' + str(accuracy_score(y_test, pred_rfc).round(2)))
print('La precision del random forest es: ' + str(precision_score(y_test, pred_rfc).round(2)))
print('El recall del random forest es: ' + str(recall_score(y_test, pred_rfc).round(2)))
print('El f1 del random forest es: ' + str(f1_score(y_test, pred_rfc).round(2)))
# Out:
# El accuracy del random forest es: 0.86
# La precision del random forest es: 0.73
# El recall del random forest es: 0.62
# El f1 del random forest es: 0.67

# %% [markdown]
# **Evaluación del modelo**
#
# El modelo demuestra un alto nivel de precisión, lo que significa que la mayoría de las predicciones positivas son correctas en comparación con el total de predicciones. Sin embargo, presenta un recall insatisfactorio, lo que indica que no logra identificar adecuadamente todos los casos positivos en el conjunto de datos. Esto puede deberse a que el modelo tiende a pasar por alto algunos ejemplos relevantes.
#
# El valor F1, que combina tanto la precisión como el recall, refleja adecuadamente esta situación. Al tener un recall bajo, el F1 también se ve afectado negativamente, ya que se calcula como la media armónica entre precisión y recall. Por lo tanto, si uno de ellos es bajo, el F1 también lo será.

# %%
# Obtiene la importancia de características
feature_importance = modelo_rfc.feature_importances_

# Crea un DataFrame con las columnas y sus respectivas importancias
importance_df = pd.DataFrame({'Columna': X.columns, 'Importancia': feature_importance})
importance_df = importance_df.sort_values(by='Importancia', ascending=False)

print(importance_df)
# Out:
#                   Columna  Importancia
# 0                    edad     0.217054
# 8               plusvalia     0.121116
# 2               educacion     0.119003
# 10  horas_trabajo_semanal     0.110442
# 5                relacion     0.098613
# 3            estado_civil     0.098052
# 4                 trabajo     0.092281
# 1           clase_trabajo     0.047168
# 9         perdida_capital     0.041264
# 11            pais_nativo     0.022747
# 6                    raza     0.018100
# 7                    sexo     0.014159

# %% [markdown]
# ## e➝ **LightGBM**

# %%
# generando y entrenando modelo
modelo_lgb = LGBMClassifier()
modelo_lgb.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
# prediciendo
pred_lgb = modelo_lgb.predict(X_test)

# %%
print('El accuracy del LightGBM es: ' + str(accuracy_score(y_test, pred_lgb).round(2)))
print('La precision del LightGBM es: ' + str(precision_score(y_test, pred_lgb).round(2)))
print('El recall del LightGBM es: ' + str(recall_score(y_test, pred_lgb).round(2)))
print('El f1 del LightGBM es: ' + str(f1_score(y_test, pred_lgb).round(2)))
# Out:
# El accuracy del LightGBM es: 0.88
# La precision del LightGBM es: 0.78
# El recall del LightGBM es: 0.64
# El f1 del LightGBM es: 0.71

# %% [markdown]
# **Evaluación del modelo**
#
# El modelo muestra una precisión y un accuracy destacables, lo que indica que es capaz de hacer predicciones precisas y acertadas en la mayoría de los casos. Sin embargo, presenta un bajo recall, lo que sugiere que no logra identificar de manera efectiva todos los casos positivos en el conjunto de datos. En otras palabras, el modelo tiende a perder algunos ejemplos relevantes y, como consecuencia, el recall es insatisfactorio.
#
# El valor F1, que es una métrica que combina tanto la precisión como el recall, se sitúa en 0.71. Esto implica que el modelo tiene un rendimiento aceptable, pero no es excepcional. Dado que el F1 es una media armónica entre precisión y recall, su valor se ve afectado por el bajo recall observado en este caso.

# %%
# Obtener la importancia de características
feature_importance = modelo_lgb.feature_importances_

# Crea un DataFrame con las columnas y sus respectivas importancias
importance_df = pd.DataFrame({'Columna': X.columns, 'Importancia': feature_importance})
importance_df = importance_df.sort_values(by='Importancia', ascending=False)

print(importance_df)
# Out:
#                   Columna  Importancia
# 0                    edad          603
# 8               plusvalia          396
# 4                 trabajo          382
# 10  horas_trabajo_semanal          366
# 9         perdida_capital          302
# 2               educacion          286
# 1           clase_trabajo          186
# 5                relacion          149
# 3            estado_civil          116
# 11            pais_nativo           96
# 6                    raza           65
# 7                    sexo           53

# %% [markdown]
# ## f➝ **LightGBM 2**

# %%
train_data = lgb.Dataset(X_train, label=y_train)

# Entrenando el modelo
modelo_lgb1 = lgb.train(
    params={
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'binary_logloss',
        'is_unbalance': True,  # Aquí se indica que las clases están desbalanceadas
    },
    train_set=train_data,
    num_boost_round=100
)
# Out:
# [LightGBM] [Info] Number of positive: 6320, number of negative: 19728
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001852 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 415
# [LightGBM] [Info] Number of data points in the train set: 26048, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242629 -> initscore=-1.138320
# [LightGBM] [Info] Start training from score -1.138320

# %%
# Realizando predicciones
y_pred = modelo_lgb1.predict(X_test)

# %%
# Puedes aplicar un umbral para obtener etiquetas binarias (0 o 1) si es necesario
y_pred_binary = [1 if y >= 0.5 else 0 for y in y_pred]

# %%
# Calcular las métricas de evaluación
accuracy_lgb1 = accuracy_score(y_test, y_pred_binary)
precision_lgb1 = precision_score(y_test, y_pred_binary)
recall_lgb1 = recall_score(y_test, y_pred_binary)
f1_lgb1 = f1_score(y_test, y_pred_binary)

# Imprimir los resultados
print('El accuracy del LightGBM_1 es: ' + str((accuracy_lgb1).round(2)))
print('La precision del LightGBM_1 es: ' + str((precision_lgb1).round(2)))
print('El recall del LightGBM_1 es: ' + str((recall_lgb1).round(2)))
print('El f1 del LightGBM_1 es: ' + str((f1_lgb1).round(2)))
# Out:
# El accuracy del LightGBM_1 es: 0.83
# La precision del LightGBM_1 es: 0.6
# El recall del LightGBM_1 es: 0.87
# El f1 del LightGBM_1 es: 0.71

# %% [markdown]
# **Evaluación del modelo**
#
# El modelo presenta un accuracy ligeramente más bajo en comparación con el modelo anterior, lo que indica que está haciendo predicciones precisas en la mayoría de los casos, pero no tan acertadas como el modelo previo.
#
# La precisión del modelo es relativamente baja con un valor de 0.6, lo que sugiere que muchas de las predicciones positivas son incorrectas en relación con el total de predicciones positivas realizadas por el modelo.
#
# Sin embargo, el recall del modelo es alto, con un valor de 0.86. Esto significa que el modelo es efectivo para identificar la mayoría de los casos positivos en el conjunto de datos.
#
# El valor F1 del modelo es de 0.71, que es el mismo que en el modelo anterior. El F1 se calcula como la media armónica entre precisión y recall, y dado que la precisión y el recall tienen valores diferentes, el F1 no se ve afectado en este caso.
#
# Aunque el F1 se mantiene igual, es importante tener en cuenta que el modelo actual tiene fortalezas y debilidades diferentes en comparación con el modelo anterior. Si bien el modelo anterior tenía una mayor precisión pero un bajo recall, este modelo tiene una alta recall pero una baja precisión.

# %%
# Obtiene la importancia de características
feature_importance = modelo_lgb1.feature_importance()

# Crea un DataFrame con las columnas y sus respectivas importancias
importance_df = pd.DataFrame({'Columna': X.columns, 'Importancia': feature_importance})
importance_df = importance_df.sort_values(by='Importancia', ascending=False)

print(importance_df)
# Out:
#                   Columna  Importancia
# 0                    edad          596
# 4                 trabajo          394
# 8               plusvalia          373
# 10  horas_trabajo_semanal          353
# 9         perdida_capital          287
# 2               educacion          273
# 1           clase_trabajo          187
# 5                relacion          151
# 3            estado_civil          138
# 11            pais_nativo          122
# 6                    raza           70
# 7                    sexo           56

# %% [markdown]
# ## g➝ **XGBOOST**

# %%
# generando y entrenando modelo
modelo_xgb = GradientBoostingClassifier()
modelo_xgb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
# prediciendo
pred_xgb = modelo_xgb.predict(X_test)

# %%
print('El accuracy del XGBOOST es: ' + str(accuracy_score(y_test, pred_lgb).round(2)))
print('La precision del XGBOOST es: ' + str(precision_score(y_test, pred_lgb).round(2)))
print('El recall del XGBOOST es: ' + str(recall_score(y_test, pred_lgb).round(2)))
print('El f1 del XGBOOST es: ' + str(f1_score(y_test, pred_lgb).round(2)))
# Out:
# El accuracy del XGBOOST es: 0.88
# La precision del XGBOOST es: 0.78
# El recall del XGBOOST es: 0.64
# El f1 del XGBOOST es: 0.71

# %% [markdown]
# **Evaluación del modelo**
#
# Este modelo muestra un rendimiento similar al segundo modelo que evaluamos. Tiene un buen accuracy, lo que indica que la mayoría de las predicciones son correctas en general. También tiene una buena precisión, lo que significa que la proporción de predicciones positivas que son realmente positivas es alta.
#
# Sin embargo, al igual que el segundo modelo, este modelo también presenta un bajo recall. Esto indica que el modelo tiene dificultades para identificar todos los casos positivos en el conjunto de datos. Es probable que el modelo esté pasando por alto algunos ejemplos relevantes y no está logrando capturarlos adecuadamente.
#
# El valor F1 de 0.71 es una métrica que combina precisión y recall. Al tener un recall bajo, el valor F1 también se ve afectado y no alcanza un rendimiento más alto.
